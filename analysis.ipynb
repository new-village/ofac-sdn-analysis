# %%
from sdnloader import load
loader = load.sdn(url="./tests/sdn_advanced.xml")

# %%
print(loader.date_of_issue)
# Out:
# {'date_of_issue': '2024-02-08'}

# %%
ind = loader.individual_list()
print(len(ind))
print(ind)
# Out:
# 15627
# ...

# %%
org = loader.organization_list()
print(len(org))
print(org)
# Out:
# 16315
# ...
